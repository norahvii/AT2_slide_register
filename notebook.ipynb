# %%
import slideio
import pytesseract
import os,glob,csv,math,json,re,math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
from IPython.display import display, HTML
from fuzzywuzzy import fuzz
from utils import show_images

# %%
# Open our folder and list the number of files inside
folder_name,type = 'A20-099','svs' # Specify the folder name (first param) and file type (second param)
folder = glob.glob(f"{folder_name}/*.{type}")
print(f"{len(folder)} {type} files identified.")
# Out:
# 86 svs files identified.

# %%
columns = ['participant_id', 'stain_id', 'brain_region','label']
csv_filename = f"{folder_name}.csv"  # Change this to your desired file name

with open(csv_filename, 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(columns)

# %%
label_count = 0

for file in folder:
    slide = slideio.open_slide(file)
    scene = slide.get_scene(0)
    # print(scene)
    # This part gets the image per slide
    image_names = slide.get_aux_image_names()
    images = []
    for name in image_names:
        if name == 'Label':
            image = slide.get_aux_image_raster(name)
            images.append(image)  
            rotated_image = np.rot90(image, k=-1) # Capture a rotated image of the label
            image_text = pytesseract.image_to_string(rotated_image)
            lines = image_text.split('\n')
            for line in lines:
                # Pattern for matching participant ID
                participant_pattern = r'([A-Z0-9]{3})-([A-Z0-9]{3})'
                # Pattern for matching brain regions
                brain_region_pattern = r'\bL\d+[A-Z]?\b'

                participant_match = re.search(participant_pattern, line)
                if participant_match:
                    participant_id = participant_match[0]

                # Brain Region Matches
                brain_region_match = re.search(brain_region_pattern, line)
                if brain_region_match:
                    brain_region = brain_region_match[0]

                # Check top right quadrent for stain
                height, width, _ = rotated_image.shape
                top_right_quadrant = rotated_image[:height//2, width//2:]
                quadrent = pytesseract.image_to_string(top_right_quadrant)
                quadrent_lines = quadrent.split('\n')
                predefined_choices = ['LB509','HE','PHF-1','TDP-43','10D5']
                # Initialize variables to store the best match and its similarity score
                stain_id = None
                best_similarity = 0
                for line in quadrent_lines:
                    for choice in predefined_choices:
                        similarity = fuzz.ratio(line, choice)  # Calculate Lebenshtein distance
                        if similarity > best_similarity:
                            best_similarity = similarity
                            stain_id = choice
            
            label_count += 1      
            print(f"------------------ files parsed: {label_count}")
            print(f"Found Participant ID: {participant_id}")
            print(f"Found Brain Region: {brain_region}")
            print(f"Found Stain ID: {stain_id}")

            with open(f'{folder_name}.csv', mode='a', newline='') as csv_file:
                csv_writer = csv.writer(csv_file)
                label = f"{participant_id}_{brain_region}_{stain_id}"
                csv_writer.writerow([participant_id, stain_id, brain_region, label])
# Out:
# ------------------ files parsed: 1
# Found Participant ID: A20-099
# Found Brain Region: L24A
# Found Stain ID: None
# ------------------ files parsed: 2
# Found Participant ID: A20-099
# Found Brain Region: L24A
# Found Stain ID: LB509
# ------------------ files parsed: 3
# Found Participant ID: A20-099
# Found Brain Region: L1
# Found Stain ID: None
# ------------------ files parsed: 4
# Found Participant ID: A20-099
# Found Brain Region: L1
# Found Stain ID: 10D5
# ------------------ files parsed: 5
# Found Participant ID: A20-099
# Found Brain Region: L11
# Found Stain ID: PHF-1
# ------------------ files parsed: 6
# Found Participant ID: A20-099
# Found Brain Region: L11
# Found Stain ID: LB509
# ------------------ files parsed: 7
# Found Participant ID: A20-099
# Found Brain Region: L1
# Found Stain ID: TDP-43
# ------------------ files parsed: 8
# Found Participant ID: A20-099
# Found Brain Region: L19
# Found Stain ID: None
# ------------------ files parsed: 9
# Found Participant ID: A20-099
# Found Brain Region: L19
# Found Stain ID: 10D5
# ------------------ files parsed: 10
# Found Participant ID: A20-099
# Found Brain Region: L19
# Found Stain ID: PHF-1
# ------------------ files parsed: 11
# Found Participant ID: A20-099
# Found Brain Region: L19
# Found Stain ID: LB509
# ------------------ files parsed: 12
# Found Participant ID: A20-099
# Found Brain Region: L19
# Found Stain ID: TDP-43
# ------------------ files parsed: 13
# Found Participant ID: A20-099
# Found Brain Region: L21
# Found Stain ID: None
# ------------------ files parsed: 14
# Found Participant ID: A20-099
# Found Brain Region: L21
# Found Stain ID: 10D5
# ------------------ files parsed: 15
# Found Participant ID: 420-099
# Found Brain Region: L21
# Found Stain ID: PHF-1
# ------------------ files parsed: 16
# Found Participant ID: 420-099
# Found Brain Region: L21
# Found Stain ID: LB509
# ------------------ files parsed: 17
# Found Participant ID: A20-099
# Found Brain Region: L21
# Found Stain ID: TDP-43
# ------------------ files parsed: 18
# Found Participant ID: A20-099
# Found Brain Region: L2
# Found Stain ID: None
# ------------------ files parsed: 19
# Found Participant ID: 420-099
# Found Brain Region: L2
# Found Stain ID: 10D5
# ------------------ files parsed: 20
# Found Participant ID: A20-099
# Found Brain Region: L21
# Found Stain ID: PHF-1
# ------------------ files parsed: 21
# Found Participant ID: A20-099
# Found Brain Region: L2
# Found Stain ID: LB509
# ------------------ files parsed: 22
# Found Participant ID: A20-099
# Found Brain Region: L3
# Found Stain ID: None
# ------------------ files parsed: 23
# Found Participant ID: A20-099
# Found Brain Region: L3
# Found Stain ID: 10D5
# ------------------ files parsed: 24
# Found Participant ID: A20-099
# Found Brain Region: L2
# Found Stain ID: TDP-43
# ------------------ files parsed: 25
# Found Participant ID: A20-099
# Found Brain Region: L31
# Found Stain ID: PHF-1
# ------------------ files parsed: 26
# Found Participant ID: A20-099
# Found Brain Region: L31
# Found Stain ID: LB509
# ------------------ files parsed: 27
# Found Participant ID: A20-099
# Found Brain Region: L3
# Found Stain ID: TDP-43
# ------------------ files parsed: 28
# Found Participant ID: A20-099
# Found Brain Region: L4
# Found Stain ID: None
# ------------------ files parsed: 29
# Found Participant ID: A20-099
# Found Brain Region: L4
# Found Stain ID: 10D5
# ------------------ files parsed: 30
# Found Participant ID: A20-099
# Found Brain Region: L41
# Found Stain ID: PHF-1
# ------------------ files parsed: 31
# Found Participant ID: A20-099
# Found Brain Region: L41
# Found Stain ID: None
# ------------------ files parsed: 32
# Found Participant ID: A20-099
# Found Brain Region: L9
# Found Stain ID: TDP-43
# ------------------ files parsed: 33
# Found Participant ID: A20-099
# Found Brain Region: L11
# Found Stain ID: None
# ------------------ files parsed: 34
# Found Participant ID: A20-099
# Found Brain Region: L11
# Found Stain ID: 10D5
# ------------------ files parsed: 35
# Found Participant ID: 420-099
# Found Brain Region: L11
# Found Stain ID: PHF-1
# ------------------ files parsed: 36
# Found Participant ID: A20-099
# Found Brain Region: L114
# Found Stain ID: LB509
# ------------------ files parsed: 37
# Found Participant ID: A20-099
# Found Brain Region: L11
# Found Stain ID: TDP-43
# ------------------ files parsed: 38
# Found Participant ID: A20-099
# Found Brain Region: L12
# Found Stain ID: None
# ------------------ files parsed: 39
# Found Participant ID: A20-099
# Found Brain Region: L12
# Found Stain ID: 10D5
# ------------------ files parsed: 40
# Found Participant ID: A20-099
# Found Brain Region: L121
# Found Stain ID: PHF-1
# ------------------ files parsed: 41
# Found Participant ID: A20-099
# Found Brain Region: L12
# Found Stain ID: LB509
# ------------------ files parsed: 42
# Found Participant ID: A20-099
# Found Brain Region: L12
# Found Stain ID: TDP-43
# ------------------ files parsed: 43
# Found Participant ID: A20-099
# Found Brain Region: L12
# Found Stain ID: None
# ------------------ files parsed: 44
# Found Participant ID: A20-099
# Found Brain Region: L12
# Found Stain ID: 10D5
# ------------------ files parsed: 45
# Found Participant ID: A20-099
# Found Brain Region: L12
# Found Stain ID: PHF-1
# ------------------ files parsed: 46
# Found Participant ID: 420-099
# Found Brain Region: L12
# Found Stain ID: LB509
# ------------------ files parsed: 47
# Found Participant ID: A20-099
# Found Brain Region: L12
# Found Stain ID: TDP-43
# ------------------ files parsed: 48
# Found Participant ID: A20-099
# Found Brain Region: L14
# Found Stain ID: None
# ------------------ files parsed: 49
# Found Participant ID: A20-099
# Found Brain Region: L14
# Found Stain ID: 10D5
# ------------------ files parsed: 50
# Found Participant ID: A20-099
# Found Brain Region: L141
# Found Stain ID: PHF-1
# ------------------ files parsed: 51
# Found Participant ID: A20-099
# Found Brain Region: L14
# Found Stain ID: TDP-43
# ------------------ files parsed: 52
# Found Participant ID: A20-099
# Found Brain Region: L30
# Found Stain ID: None
# ------------------ files parsed: 53
# Found Participant ID: A20-099
# Found Brain Region: L30
# Found Stain ID: 10D5
# ------------------ files parsed: 54
# Found Participant ID: A20-099
# Found Brain Region: L30
# Found Stain ID: PHF-1
# ------------------ files parsed: 55
# Found Participant ID: A20-099
# Found Brain Region: L30
# Found Stain ID: None
# ------------------ files parsed: 56
# Found Participant ID: A20-099
# Found Brain Region: L30
# Found Stain ID: TDP-43
# ------------------ files parsed: 57
# Found Participant ID: A20-099
# Found Brain Region: L41
# Found Stain ID: LB509
# ------------------ files parsed: 58
# Found Participant ID: A20-099
# Found Brain Region: L4
# Found Stain ID: TDP-43
# ------------------ files parsed: 59
# Found Participant ID: A20-099
# Found Brain Region: L23
# Found Stain ID: None
# ------------------ files parsed: 60
# Found Participant ID: A20-099
# Found Brain Region: L23
# Found Stain ID: 10D5
# ------------------ files parsed: 61
# Found Participant ID: A20-099
# Found Brain Region: L23
# Found Stain ID: PHF-1
# ------------------ files parsed: 62
# Found Participant ID: A20-099
# Found Brain Region: L23
# Found Stain ID: LB509
# ------------------ files parsed: 63
# Found Participant ID: A20-099
# Found Brain Region: L23
# Found Stain ID: TDP-43
# ------------------ files parsed: 64
# Found Participant ID: A20-099
# Found Brain Region: L23
# Found Stain ID: None
# ------------------ files parsed: 65
# Found Participant ID: A20-099
# Found Brain Region: L5
# Found Stain ID: 10D5
# ------------------ files parsed: 66
# Found Participant ID: A20-099
# Found Brain Region: L5
# Found Stain ID: PHF-1
# ------------------ files parsed: 67
# Found Participant ID: A20-099
# Found Brain Region: L5
# Found Stain ID: None
# ------------------ files parsed: 68
# Found Participant ID: A20-099
# Found Brain Region: L5
# Found Stain ID: TDP-43
# ------------------ files parsed: 69
# Found Participant ID: A20-099
# Found Brain Region: L6
# Found Stain ID: None
# ------------------ files parsed: 70
# Found Participant ID: A20-099
# Found Brain Region: L6
# Found Stain ID: 10D5
# ------------------ files parsed: 71
# Found Participant ID: A20-099
# Found Brain Region: L61
# Found Stain ID: PHF-1
# ------------------ files parsed: 72
# Found Participant ID: A20-099
# Found Brain Region: L6
# Found Stain ID: LB509
# ------------------ files parsed: 73
# Found Participant ID: A20-099
# Found Brain Region: L6
# Found Stain ID: TDP-43
# ------------------ files parsed: 74
# Found Participant ID: A20-099
# Found Brain Region: L17
# Found Stain ID: 10D5
# ------------------ files parsed: 75
# Found Participant ID: A20-099
# Found Brain Region: L17
# Found Stain ID: 10D5
# ------------------ files parsed: 76
# Found Participant ID: A20-099
# Found Brain Region: L17
# Found Stain ID: PHF-1
# ------------------ files parsed: 77
# Found Participant ID: A20-099
# Found Brain Region: L17
# Found Stain ID: LB509
# ------------------ files parsed: 78
# Found Participant ID: A20-099
# Found Brain Region: L17
# Found Stain ID: TDP-43
# ------------------ files parsed: 79
# Found Participant ID: A20-099
# Found Brain Region: L8
# Found Stain ID: None
# ------------------ files parsed: 80
# Found Participant ID: 920-099
# Found Brain Region: L8
# Found Stain ID: 10D5
# ------------------ files parsed: 81
# Found Participant ID: A20-099
# Found Brain Region: L81
# Found Stain ID: PHF-1
# ------------------ files parsed: 82
# Found Participant ID: A20-099
# Found Brain Region: L8
# Found Stain ID: LB509
# ------------------ files parsed: 83
# Found Participant ID: A20-099
# Found Brain Region: L8
# Found Stain ID: TDP-43
# ------------------ files parsed: 84
# Found Participant ID: A20-099
# Found Brain Region: L9
# Found Stain ID: None
# ------------------ files parsed: 85
# Found Participant ID: A20-099
# Found Brain Region: L9
# Found Stain ID: 10D5
# ------------------ files parsed: 86
# Found Participant ID: A20-099
# Found Brain Region: L91
# Found Stain ID: PHF-1
